# %% [markdown]
# # Causal Learning

# %% [markdown]
# ## Imports

# %%
import os, sys
import warnings
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

from causalnex.discretiser import Discretiser
from causalnex.structure import DAGRegressor
from causalnex.inference import InferenceEngine
from causalnex.network import BayesianNetwork
from causalnex.network.sklearn import BayesianNetworkClassifier
from causalnex.structure.notears import from_pandas
from causalnex.utils.network_utils import get_markov_blanket
from causalnex.structure.notears import from_pandas, from_pandas_lasso
from causalnex.discretiser.discretiser_strategy import ( DecisionTreeSupervisedDiscretiserMethod )
from sklearn.model_selection import KFold
from sklearn.model_selection import train_test_split
from sklearn.metrics import recall_score, f1_score, accuracy_score, precision_score
import warnings
warnings.filterwarnings('ignore')

# %%
sns.set()
# %matplotlib inline
pd.set_option('display.max_columns', None)
pd.set_option('display.max_colwidth', None)
pd.set_option("expand_frame_repr", False)
pd.set_option('display.float_format', '{:.2f}'.format)

# %%
sys.path.append(os.path.abspath(os.path.join('../scripts')))

# %%
from file_handler import FileHandler
import vis_seaborn as vs
from eda_helper import Helper
from df_overview import DfOverview
from ScalerNormalizer import ScalerNormalizer

# %%
helper = Helper()
sn = ScalerNormalizer()

# %% [markdown]
# ## Data reading

# %%
df = pd.read_csv("../data/data.csv")
df.head(5)
# Out:
#          id diagnosis  radius_mean  texture_mean  perimeter_mean  area_mean  smoothness_mean  compactness_mean  concavity_mean  concave points_mean  symmetry_mean  fractal_dimension_mean  radius_se  texture_se  perimeter_se  area_se  smoothness_se  compactness_se  concavity_se  concave points_se  symmetry_se  fractal_dimension_se  radius_worst  texture_worst  perimeter_worst  area_worst  smoothness_worst  compactness_worst  concavity_worst  concave points_worst  symmetry_worst  fractal_dimension_worst  Unnamed: 32
# 0    842302         M        17.99         10.38          122.80    1001.00             0.12              0.28            0.30                 0.15           0.24                    0.08       1.09        0.91          8.59   153.40           0.01            0.05          0.05               0.02         0.03                  0.01         25.38          17.33           184.60     2019.00              0.16               0.67             0.71                  0.27            0.46                     0.12          NaN
# 1    842517         M        20.57         17.77          132.90    1326.00             0.08              0.08            0.09                 0.07           0.18                    0.06       0.54        0.73          3.40    74.08           0.01            0.01          0.02               0.01         0.01                  0.00         24.99          23.41           158.80     1956.00              0.12               0.19             0.24                  0.19            0.28                     0.09          NaN
# 2  84300903         M        19.69         21.25          130.00    1203.00             0.11              0.16            0.20                 0.13           0.21                    0.06       0.75        0.79          4.58    94.03           0.01            0.04          0.04               0.02         0.02                  0.00         23.57          25.53           152.50     1709.00              0.14               0.42             0.45                  0.24            0.36                     0.09          NaN
# 3  84348301         M        11.42         20.38           77.58     386.10             0.14              0.28            0.24                 0.11           0.26                    0.10       0.50        1.16          3.44    27.23           0.01            0.07          0.06               0.02         0.06                  0.01         14.91          26.50            98.87      567.70              0.21               0.87             0.69                  0.26            0.66                     0.17          NaN
# 4  84358402         M        20.29         14.34          135.10    1297.00             0.10              0.13            0.20                 0.10           0.18                    0.06       0.76        0.78          5.44    94.44           0.01            0.02          0.06               0.02         0.02                  0.01         22.54          16.67           152.20     1575.00              0.14               0.20             0.40                  0.16            0.24                     0.08          NaN

# %%
feat = ['diagnosis', 'perimeter_worst', 'area_worst', 'radius_worst', 'concave points_worst', 'concave points_mean', 'perimeter_mean', 'area_mean', 'radius_mean', 'area_se', 'concavity_mean', 'concavity_worst', 'perimeter_se', 'radius_se', 'compactness_worst', 'compactness_mean', 'texture_worst', 'concave points_se', 'smoothness_worst', 'texture_mean', 'symmetry_worst', 'concavity_se', 'smoothness_mean', 'symmetry_mean', 'compactness_se', 'fractal_dimension_worst', 'fractal_dimension_se', 'texture_se', 'fractal_dimension_mean', 'symmetry_se', 'smoothness_se']

# %%
x = df[feat[:29]]
x['diagnosis'] = x['diagnosis'].apply(lambda x: 1 if x == "M" else 0)
x.head(5)
# Out:
#    diagnosis  perimeter_worst  area_worst  radius_worst  concave points_worst  concave points_mean  perimeter_mean  area_mean  radius_mean  area_se  concavity_mean  concavity_worst  perimeter_se  radius_se  compactness_worst  compactness_mean  texture_worst  concave points_se  smoothness_worst  texture_mean  symmetry_worst  concavity_se  smoothness_mean  symmetry_mean  compactness_se  fractal_dimension_worst  fractal_dimension_se  texture_se  fractal_dimension_mean
# 0          1           184.60     2019.00         25.38                  0.27                 0.15          122.80    1001.00        17.99   153.40            0.30             0.71          8.59       1.09               0.67              0.28          17.33               0.02              0.16         10.38            0.46          0.05             0.12           0.24            0.05                     0.12                  0.01        0.91                    0.08
# 1          1           158.80     1956.00         24.99                  0.19                 0.07          132.90    1326.00        20.57    74.08            0.09             0.24          3.40       0.54               0.19              0.08          23.41               0.01              0.12         17.77            0.28          0.02             0.08           0.18            0.01                     0.09                  0.00        0.73                    0.06
# 2          1           152.50     1709.00         23.57                  0.24                 0.13          130.00    1203.00        19.69    94.03            0.20             0.45          4.58       0.75               0.42              0.16          25.53               0.02              0.14         21.25            0.36          0.04             0.11           0.21            0.04                     0.09                  0.00        0.79                    0.06
# 3          1            98.87      567.70         14.91                  0.26                 0.11           77.58     386.10        11.42    27.23            0.24             0.69          3.44       0.50               0.87              0.28          26.50               0.02              0.21         20.38            0.66          0.06             0.14           0.26            0.07                     0.17                  0.01        1.16                    0.10
# 4          1           152.20     1575.00         22.54                  0.16                 0.10          135.10    1297.00        20.29    94.44            0.20             0.40          5.44       0.76               0.20              0.13          16.67               0.02              0.14         14.34            0.24          0.06             0.10           0.18            0.02                     0.08                  0.01        0.78                    0.06

# %%
num_feat = x.shape[1]-1
#print(num_feat)
fig = plt.figure(figsize=(25, num_feat))
fig.subplots_adjust(hspace=.5)
axs = [fig.add_subplot(int(num_feat / 4), 4, i + 1) for i in range(num_feat)]

for i, column in enumerate(x.columns[1:]):
    sns.distplot(x[x.diagnosis == 1][column], ax=axs[i], color='darkorange', label="M")
    sns.distplot(x[x.diagnosis == 0][column], ax=axs[i], color='darkgreen', label="B")
    axs[i].set_title('Distribution for {}'.format( column), fontweight='bold', fontsize=15)
    axs[i].legend(fontsize=20)
plt.show()

# %% [markdown]
# ## Normalize the data

# %%
features = x.iloc[:, 1:]
features
# Out:
#      perimeter_worst  area_worst  radius_worst  concave points_worst  concave points_mean  perimeter_mean  area_mean  radius_mean  area_se  concavity_mean  concavity_worst  perimeter_se  radius_se  compactness_worst  compactness_mean  texture_worst  concave points_se  smoothness_worst  texture_mean  symmetry_worst  concavity_se  smoothness_mean  symmetry_mean  compactness_se  fractal_dimension_worst  fractal_dimension_se  texture_se  fractal_dimension_mean
# 0             184.60     2019.00         25.38                  0.27                 0.15          122.80    1001.00        17.99   153.40            0.30             0.71          8.59       1.09               0.67              0.28          17.33               0.02              0.16         10.38            0.46          0.05             0.12           0.24            0.05                     0.12                  0.01        0.91                    0.08
# 1             158.80     1956.00         24.99                  0.19                 0.07          132.90    1326.00        20.57    74.08            0.09             0.24          3.40       0.54               0.19              0.08          23.41               0.01              0.12         17.77            0.28          0.02             0.08           0.18            0.01                     0.09                  0.00        0.73                    0.06
# 2             152.50     1709.00         23.57                  0.24                 0.13          130.00    1203.00        19.69    94.03            0.20             0.45          4.58       0.75               0.42              0.16          25.53               0.02              0.14         21.25            0.36          0.04             0.11           0.21            0.04                     0.09                  0.00        0.79                    0.06
# 3              98.87      567.70         14.91                  0.26                 0.11           77.58     386.10        11.42    27.23            0.24             0.69          3.44       0.50               0.87              0.28          26.50               0.02              0.21         20.38            0.66          0.06             0.14           0.26            0.07                     0.17                  0.01        1.16                    0.10
# 4             152.20     1575.00         22.54                  0.16                 0.10          135.10    1297.00        20.29    94.44            0.20             0.40          5.44       0.76               0.20              0.13          16.67               0.02              0.14         14.34            0.24          0.06             0.10           0.18            0.02                     0.08                  0.01        0.78                    0.06
# ..               ...         ...           ...                   ...                  ...             ...        ...          ...      ...             ...              ...           ...        ...                ...               ...            ...                ...               ...           ...             ...           ...              ...            ...             ...                      ...                   ...         ...                     ...
# 564           166.10     2027.00         25.45                  0.22                 0.14          142.00    1479.00        21.56   158.70            0.24             0.41          7.67       1.18               0.21              0.12          26.40               0.02              0.14         22.39            0.21          0.05             0.11           0.17            0.03                     0.07                  0.00        1.26                    0.06
# 565           155.00     1731.00         23.69                  0.16                 0.10          131.20    1261.00        20.13    99.04            0.14             0.32          5.20       0.77               0.19              0.10          38.25               0.02              0.12         28.25            0.26          0.04             0.10           0.18            0.02                     0.07                  0.00        2.46                    0.06
# 566           126.70     1124.00         18.98                  0.14                 0.05          108.30     858.10        16.60    48.55            0.09             0.34          3.42       0.46               0.31              0.10          34.12               0.02              0.11         28.08            0.22          0.05             0.08           0.16            0.04                     0.08                  0.00        1.07                    0.06
# 567           184.60     1821.00         25.74                  0.27                 0.15          140.10    1265.00        20.60    86.22            0.35             0.94          5.77       0.73               0.87              0.28          39.42               0.02              0.17         29.33            0.41          0.07             0.12           0.24            0.06                     0.12                  0.01        1.59                    0.07
# 568            59.16      268.60          9.46                  0.00                 0.00           47.92     181.00         7.76    19.15            0.00             0.00          2.55       0.39               0.06              0.04          30.37               0.00              0.09         24.54            0.29          0.00             0.05           0.16            0.00                     0.07                  0.00        1.43                    0.06
#
# [569 rows x 28 columns]

# %%
normal_data = sn.scale_and_normalize(features, features.columns.to_list())
normal_data.insert(loc=0, column='diagnosis', value=x['diagnosis'])
normal_data
# Out:
#      diagnosis  perimeter_worst  area_worst  radius_worst  concave points_worst  concave points_mean  perimeter_mean  area_mean  radius_mean  area_se  concavity_mean  concavity_worst  perimeter_se  radius_se  compactness_worst  compactness_mean  texture_worst  concave points_se  smoothness_worst  texture_mean  symmetry_worst  concavity_se  smoothness_mean  symmetry_mean  compactness_se  fractal_dimension_worst  fractal_dimension_se  texture_se  fractal_dimension_mean
# 0            1             0.24        0.16          0.22                  0.33                 0.26            0.20       0.13         0.19     0.10            0.25             0.21          0.13       0.13               0.22              0.29           0.05               0.11              0.22          0.01            0.22          0.05             0.21           0.25            0.13                     0.15                  0.07        0.04                    0.22
# 1            1             0.30        0.24          0.33                  0.35                 0.19            0.34       0.27         0.35     0.07            0.11             0.11          0.07       0.09               0.08              0.10           0.17               0.14              0.19          0.15            0.13          0.03             0.16           0.21            0.04                     0.12                  0.05        0.05                    0.08
# 2            1             0.23        0.17          0.25                  0.37                 0.28            0.26       0.20         0.27     0.07            0.21             0.16          0.08       0.10               0.17              0.19           0.16               0.17              0.21          0.17            0.18          0.04             0.23           0.23            0.13                     0.09                  0.06        0.04                    0.09
# 3            1             0.08        0.03          0.08                  0.30                 0.18            0.08       0.03         0.07     0.01            0.19             0.18          0.04       0.05               0.27              0.27           0.13               0.12              0.31          0.12            0.34          0.05             0.27           0.26            0.18                     0.26                  0.10        0.06                    0.34
# 4            1             0.26        0.18          0.27                  0.29                 0.27            0.33       0.25         0.33     0.09            0.24             0.17          0.11       0.12               0.09              0.18           0.06               0.19              0.23          0.08            0.08          0.07             0.22           0.20            0.09                     0.07                  0.08        0.05                    0.10
# ..         ...              ...         ...           ...                   ...                  ...             ...        ...          ...      ...             ...              ...           ...        ...                ...               ...            ...                ...               ...           ...             ...           ...              ...            ...             ...                      ...                   ...         ...                     ...
# 564          1             0.25        0.19          0.27                  0.33                 0.30            0.29       0.24         0.30     0.12            0.25             0.14          0.14       0.17               0.08              0.13           0.16               0.20              0.20          0.18            0.04          0.06             0.23           0.14            0.09                     0.05                  0.05        0.08                    0.06
# 565          1             0.25        0.18          0.27                  0.27                 0.23            0.29       0.23         0.30     0.08            0.16             0.12          0.10       0.11               0.08              0.12           0.34               0.15              0.14          0.30            0.10          0.05             0.20           0.17            0.08                     0.04                  0.03        0.22                    0.05
# 566          1             0.23        0.14          0.24                  0.30                 0.16            0.27       0.18         0.28     0.05            0.13             0.17          0.08       0.08               0.17              0.16           0.36               0.18              0.17          0.38            0.08          0.07             0.18           0.16            0.16                     0.09                  0.06        0.10                    0.08
# 567          1             0.22        0.13          0.21                  0.30                 0.25            0.22       0.16         0.21     0.05            0.27             0.24          0.08       0.07               0.27              0.26           0.24               0.10              0.20          0.22            0.16          0.06             0.19           0.22            0.15                     0.15                  0.06        0.09                    0.14
# 568          0             0.05        0.02          0.06                  0.00                 0.00            0.03       0.02         0.04     0.03            0.00             0.00          0.10       0.11               0.04              0.08           0.55               0.00              0.14          0.57            0.29          0.00             0.00           0.30            0.02                     0.11                  0.07        0.27                    0.21
#
# [569 rows x 29 columns]

# %%
# %%time
sm = from_pandas(normal_data.iloc[:, :9], tabu_parent_nodes=['diagnosis'],)
# Out:
# CPU times: total: 12.1 s
# Wall time: 12.5 s

# %%
vs.vis_sm(sm)

# %%
sm.remove_edges_below_threshold(0.8)
vs.vis_sm(sm)

# %% [markdown]
# ## Stablity of causal graph

# %%
x_selected = normal_data.iloc[:, :10]

# %% [markdown]
# ### 50%

# %%
portion = int(x_selected.shape[0] *.5)
x_portion = x_selected.head(portion)

# %%
# %%time
sm1 = from_pandas(x_portion, tabu_parent_nodes=['diagnosis'])
sm1.remove_edges_below_threshold(0.8)
sm1 = sm1.get_largest_subgraph()
vs.vis_sm(sm1)
# Out:
# CPU times: total: 16 s
# Wall time: 17.4 s

# %%
print(sm1.edges)
# Out:
# [('perimeter_worst', 'diagnosis'), ('perimeter_worst', 'radius_worst'), ('perimeter_worst', 'concave points_worst'), ('perimeter_worst', 'concave points_mean'), ('area_worst', 'diagnosis'), ('area_worst', 'perimeter_worst'), ('area_worst', 'concave points_worst'), ('radius_worst', 'diagnosis'), ('radius_worst', 'concave points_worst'), ('radius_worst', 'concave points_mean'), ('concave points_mean', 'diagnosis'), ('concave points_mean', 'concave points_worst'), ('perimeter_mean', 'diagnosis'), ('perimeter_mean', 'concave points_mean'), ('perimeter_mean', 'radius_mean'), ('area_mean', 'diagnosis'), ('area_mean', 'perimeter_mean'), ('radius_mean', 'diagnosis'), ('radius_mean', 'concave points_mean'), ('area_se', 'area_worst')]

# %% [markdown]
# # 60%

# %%
portion = int(x_selected.shape[0]*.6)
x_portion = x_selected.head(portion)

# %%
# %%time
sm2 = from_pandas(x_portion, tabu_parent_nodes=['diagnosis'],)
sm2.remove_edges_below_threshold(0.8)
sm2 = sm2.get_largest_subgraph()
vs.vis_sm(sm2)
# Out:
# CPU times: total: 15.6 s
# Wall time: 16.8 s

# %%
def jaccard_similarity(g, h):
    i = set(g).intersection(h)
    return round(len(i) / (len(g) + len(h) - len(i)), 3)

# %%
jaccard_similarity(sm1.edges, sm2.edges)
# Out:
# 0.952

# %% [markdown]
# # 70%

# %%
portion = int(x_selected.shape[0]*.7)
x_portion = x_selected.head(portion)

# %%
# %%time
sm3 = from_pandas(x_portion, tabu_parent_nodes=['diagnosis'],)
sm3.remove_edges_below_threshold(0.8)
sm3 = sm3.get_largest_subgraph()
vs.vis_sm(sm3)
# Out:
# CPU times: total: 17.6 s
# Wall time: 18.6 s

# %%
jaccard_similarity(sm2.edges, sm3.edges)
# Out:
# 0.818

# %% [markdown]
# # 80%

# %%
portion = int(x_selected.shape[0] * .8)
x_portion = x_selected.head(portion)

# %%
# %%time
sm4 = from_pandas(x_portion, tabu_parent_nodes=['diagnosis'],)
sm4.remove_edges_below_threshold(0.8)
sm4 = sm4.get_largest_subgraph()
vs.vis_sm(sm4)
# Out:
# CPU times: total: 15.3 s
# Wall time: 16.1 s

# %%
jaccard_similarity(sm3.edges, sm4.edges)
# Out:
# 1.0

# %% [markdown]
# # 90%

# %%
portion = int(x_selected.shape[0] * .9)
x_portion = x_selected.head(portion)

# %%
# %%time
sm5 = from_pandas(x_portion, tabu_parent_nodes=['diagnosis'],)
sm5.remove_edges_below_threshold(0.8)
sm5 = sm5.get_largest_subgraph()
vs.vis_sm(sm5)
# Out:
# CPU times: total: 16.8 s
# Wall time: 17.7 s

# %% [markdown]
# Casual Inference model for breast cancer

# %%
jaccard_similarity(sm5.edges, sm4.edges)
# Out:
# 0.947

# %% [markdown]
# # 100%

# %%
# %%time
sm = from_pandas(x_selected, tabu_parent_nodes=['diagnosis'],)
sm.remove_edges_below_threshold(0.8)
sm = sm.get_largest_subgraph()
vs.vis_sm(sm)
# Out:
# CPU times: total: 16.9 s
# Wall time: 18.1 s

# %%
jaccard_similarity(sm.edges, sm5.edges)
# Out:
# 0.947

# %% [markdown]
# ## Reducing a graph to its Markov Blanket

# %% [markdown]
# Now, assume that target is our variable of interest. We actually do not need all the nodes in the network but only the MB of target. To achieve that, we simply need to use the get_markov_blanket function from causalnex. Specifically,

# %%
bn = BayesianNetwork(sm)
blanket = get_markov_blanket(bn, 'diagnosis')
edge_list = list(blanket.structure.edges)
edge_list
# Out:
# [('perimeter_worst', 'diagnosis'),
#  ('perimeter_worst', 'radius_worst'),
#  ('perimeter_worst', 'concave points_mean'),
#  ('area_worst', 'diagnosis'),
#  ('area_worst', 'perimeter_worst'),
#  ('radius_worst', 'diagnosis'),
#  ('radius_worst', 'concave points_mean'),
#  ('concave points_mean', 'diagnosis'),
#  ('perimeter_mean', 'diagnosis'),
#  ('perimeter_mean', 'concave points_mean'),
#  ('perimeter_mean', 'radius_mean'),
#  ('area_mean', 'diagnosis'),
#  ('area_mean', 'perimeter_mean'),
#  ('radius_mean', 'diagnosis'),
#  ('radius_mean', 'concave points_mean')]

# %%
vs.vis_sm(blanket.structure)

# %% [markdown]
# ## Discretising Numeric Features

# %%
x_selected = x.iloc[:, :10]
x_selected
# Out:
#      diagnosis  perimeter_worst  area_worst  radius_worst  concave points_worst  concave points_mean  perimeter_mean  area_mean  radius_mean  area_se
# 0            1           184.60     2019.00         25.38                  0.27                 0.15          122.80    1001.00        17.99   153.40
# 1            1           158.80     1956.00         24.99                  0.19                 0.07          132.90    1326.00        20.57    74.08
# 2            1           152.50     1709.00         23.57                  0.24                 0.13          130.00    1203.00        19.69    94.03
# 3            1            98.87      567.70         14.91                  0.26                 0.11           77.58     386.10        11.42    27.23
# 4            1           152.20     1575.00         22.54                  0.16                 0.10          135.10    1297.00        20.29    94.44
# ..         ...              ...         ...           ...                   ...                  ...             ...        ...          ...      ...
# 564          1           166.10     2027.00         25.45                  0.22                 0.14          142.00    1479.00        21.56   158.70
# 565          1           155.00     1731.00         23.69                  0.16                 0.10          131.20    1261.00        20.13    99.04
# 566          1           126.70     1124.00         18.98                  0.14                 0.05          108.30     858.10        16.60    48.55
# 567          1           184.60     1821.00         25.74                  0.27                 0.15          140.10    1265.00        20.60    86.22
# 568          0            59.16      268.60          9.46                  0.00                 0.00           47.92     181.00         7.76    19.15
#
# [569 rows x 10 columns]

# %%
df_overview = DfOverview(x_selected)
overview = df_overview.getOverview()
vs.view_df(overview[["count", "unique_value_count", "unique_percentage"]],
                    ["count", "unique_value_count"])
# Out:
# <style type="text/css">
# #T_3b0cf_row0_col0, #T_3b0cf_row0_col3, #T_3b0cf_row1_col0, #T_3b0cf_row1_col3, #T_3b0cf_row2_col0, #T_3b0cf_row2_col3, #T_3b0cf_row3_col0, #T_3b0cf_row3_col3, #T_3b0cf_row4_col0, #T_3b0cf_row4_col3, #T_3b0cf_row5_col0, #T_3b0cf_row5_col3, #T_3b0cf_row6_col0, #T_3b0cf_row6_col3, #T_3b0cf_row7_col0, #T_3b0cf_row7_col3, #T_3b0cf_row8_col0, #T_3b0cf_row8_col3, #T_3b0cf_row9_col0, #T_3b0cf_row9_col3 {
#   background-color: white;
#   color: black;
# }
# #T_3b0cf_row0_col1, #T_3b0cf_row1_col1, #T_3b0cf_row2_col1, #T_3b0cf_row3_col1, #T_3b0cf_row4_col1, #T_3b0cf_row5_col1, #T_3b0cf_row6_col1, #T_3b0cf_row7_col1, #T_3b0cf_row8_col1, #T_3b0cf_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #66F582 100.0%, transparent 100.0%);
#   background-color: white;
#   color: black;
# }
# #T_3b0cf_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #66F582 0.4%, transparent 0.4%);
#   background-color: white;
#   color: black;
# }
# #T_3b0cf_row1_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #66F582 90.3%, transparent 90.3%);
#   background-color: white;
#   color: black;
# }
# #T_3b0cf_row2_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #66F582 95.6%, transparent 95.6%);
#   background-color: white;
#   color: black;
# }
# #T_3b0cf_row3_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #66F582 80.3%, transparent 80.3%);
#   background-color: white;
#   color: black;
# }
# #T_3b0cf_row4_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #66F582 86.5%, transparent 86.5%);
#   background-color: white;
#   color: black;
# }
# #T_3b0cf_row5_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #66F582 95.3%, transparent 95.3%);
#   background-color: white;
#   color: black;
# }
# #T_3b0cf_row6_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #66F582 91.7%, transparent 91.7%);
#   background-color: white;
#   color: black;
# }
# #T_3b0cf_row7_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #66F582 94.7%, transparent 94.7%);
#   background-color: white;
#   color: black;
# }
# #T_3b0cf_row8_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #66F582 80.1%, transparent 80.1%);
#   background-color: white;
#   color: black;
# }
# #T_3b0cf_row9_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #66F582 92.8%, transparent 92.8%);
#   background-color: white;
#   color: black;
# }
# </style>
# <table id="T_3b0cf" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3b0cf_level0_col0" class="col_heading level0 col0" >label</th>
#       <th id="T_3b0cf_level0_col1" class="col_heading level0 col1" >count</th>
#       <th id="T_3b0cf_level0_col2" class="col_heading level0 col2" >unique_value_count</th>
#       <th id="T_3b0cf_level0_col3" class="col_heading level0 col3" >unique_percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3b0cf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_3b0cf_row0_col0" class="data row0 col0" >DIAGNOSIS</td>
#       <td id="T_3b0cf_row0_col1" class="data row0 col1" >569</td>
#       <td id="T_3b0cf_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_3b0cf_row0_col3" class="data row0 col3" >0.35%</td>
#     </tr>
#     <tr>
#       <th id="T_3b0cf_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_3b0cf_row1_col0" class="data row1 col0" >PERIMETER_WORST</td>
#       <td id="T_3b0cf_row1_col1" class="data row1 col1" >569</td>
#       <td id="T_3b0cf_row1_col2" class="data row1 col2" >514</td>
#       <td id="T_3b0cf_row1_col3" class="data row1 col3" >90.33%</td>
#     </tr>
#     <tr>
#       <th id="T_3b0cf_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_3b0cf_row2_col0" class="data row2 col0" >AREA_WORST</td>
#       <td id="T_3b0cf_row2_col1" class="data row2 col1" >569</td>
#       <td id="T_3b0cf_row2_col2" class="data row2 col2" >544</td>
#       <td id="T_3b0cf_row2_col3" class="data row2 col3" >95.61%</td>
#     </tr>
#     <tr>
#       <th id="T_3b0cf_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_3b0cf_row3_col0" class="data row3 col0" >RADIUS_WORST</td>
#       <td id="T_3b0cf_row3_col1" class="data row3 col1" >569</td>
#       <td id="T_3b0cf_row3_col2" class="data row3 col2" >457</td>
#       <td id="T_3b0cf_row3_col3" class="data row3 col3" >80.32%</td>
#     </tr>
#     <tr>
#       <th id="T_3b0cf_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_3b0cf_row4_col0" class="data row4 col0" >CONCAVE POINTS_WORST</td>
#       <td id="T_3b0cf_row4_col1" class="data row4 col1" >569</td>
#       <td id="T_3b0cf_row4_col2" class="data row4 col2" >492</td>
#       <td id="T_3b0cf_row4_col3" class="data row4 col3" >86.47%</td>
#     </tr>
#     <tr>
#       <th id="T_3b0cf_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_3b0cf_row5_col0" class="data row5 col0" >CONCAVE POINTS_MEAN</td>
#       <td id="T_3b0cf_row5_col1" class="data row5 col1" >569</td>
#       <td id="T_3b0cf_row5_col2" class="data row5 col2" >542</td>
#       <td id="T_3b0cf_row5_col3" class="data row5 col3" >95.25%</td>
#     </tr>
#     <tr>
#       <th id="T_3b0cf_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_3b0cf_row6_col0" class="data row6 col0" >PERIMETER_MEAN</td>
#       <td id="T_3b0cf_row6_col1" class="data row6 col1" >569</td>
#       <td id="T_3b0cf_row6_col2" class="data row6 col2" >522</td>
#       <td id="T_3b0cf_row6_col3" class="data row6 col3" >91.74%</td>
#     </tr>
#     <tr>
#       <th id="T_3b0cf_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_3b0cf_row7_col0" class="data row7 col0" >AREA_MEAN</td>
#       <td id="T_3b0cf_row7_col1" class="data row7 col1" >569</td>
#       <td id="T_3b0cf_row7_col2" class="data row7 col2" >539</td>
#       <td id="T_3b0cf_row7_col3" class="data row7 col3" >94.73%</td>
#     </tr>
#     <tr>
#       <th id="T_3b0cf_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_3b0cf_row8_col0" class="data row8 col0" >RADIUS_MEAN</td>
#       <td id="T_3b0cf_row8_col1" class="data row8 col1" >569</td>
#       <td id="T_3b0cf_row8_col2" class="data row8 col2" >456</td>
#       <td id="T_3b0cf_row8_col3" class="data row8 col3" >80.14%</td>
#     </tr>
#     <tr>
#       <th id="T_3b0cf_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_3b0cf_row9_col0" class="data row9 col0" >AREA_SE</td>
#       <td id="T_3b0cf_row9_col1" class="data row9 col1" >569</td>
#       <td id="T_3b0cf_row9_col2" class="data row9 col2" >528</td>
#       <td id="T_3b0cf_row9_col3" class="data row9 col3" >92.79%</td>
#     </tr>
#   </tbody>
# </table>

# %%
features = list(x_selected.columns.difference(['diagnosis']))
features
# Out:
# ['area_mean',
#  'area_se',
#  'area_worst',
#  'concave points_mean',
#  'concave points_worst',
#  'perimeter_mean',
#  'perimeter_worst',
#  'radius_mean',
#  'radius_worst']

# %%
tree_discretiser = DecisionTreeSupervisedDiscretiserMethod(
    mode='single',
    tree_params={'max_depth': 3, 'random_state': 27},
)
tree_discretiser.fit(
    feat_names=features,
    dataframe=x,
    target_continuous=True,
    target='diagnosis',
)
tree_discretiser
# Out:
# DecisionTreeSupervisedDiscretiserMethod(tree_params={'max_depth': 3,
#                                                      'random_state': 27})

# %%
discretised_data = x_selected.copy()
for col in features:
    discretised_data[col] = tree_discretiser.transform(x_selected[[col]])

# %%
df_overview = DfOverview(discretised_data)
overview = df_overview.getOverview()
vs.view_df(overview[["count", "unique_value_count", "unique_percentage"]],
           ["count", "unique_value_count"])
# Out:
# <style type="text/css">
# #T_dd26d_row0_col0, #T_dd26d_row0_col3, #T_dd26d_row1_col0, #T_dd26d_row1_col3, #T_dd26d_row2_col0, #T_dd26d_row2_col3, #T_dd26d_row3_col0, #T_dd26d_row3_col3, #T_dd26d_row4_col0, #T_dd26d_row4_col3, #T_dd26d_row5_col0, #T_dd26d_row5_col3, #T_dd26d_row6_col0, #T_dd26d_row6_col3, #T_dd26d_row7_col0, #T_dd26d_row7_col3, #T_dd26d_row8_col0, #T_dd26d_row8_col3, #T_dd26d_row9_col0, #T_dd26d_row9_col3 {
#   background-color: white;
#   color: black;
# }
# #T_dd26d_row0_col1, #T_dd26d_row1_col1, #T_dd26d_row2_col1, #T_dd26d_row3_col1, #T_dd26d_row4_col1, #T_dd26d_row5_col1, #T_dd26d_row6_col1, #T_dd26d_row7_col1, #T_dd26d_row8_col1, #T_dd26d_row9_col1 {
#   width: 10em;
#   background: linear-gradient(90deg, #66F582 100.0%, transparent 100.0%);
#   background-color: white;
#   color: black;
# }
# #T_dd26d_row0_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #66F582 0.4%, transparent 0.4%);
#   background-color: white;
#   color: black;
# }
# #T_dd26d_row1_col2, #T_dd26d_row2_col2, #T_dd26d_row3_col2, #T_dd26d_row4_col2, #T_dd26d_row5_col2, #T_dd26d_row6_col2, #T_dd26d_row7_col2, #T_dd26d_row8_col2, #T_dd26d_row9_col2 {
#   width: 10em;
#   background: linear-gradient(90deg, #66F582 1.4%, transparent 1.4%);
#   background-color: white;
#   color: black;
# }
# </style>
# <table id="T_dd26d" style='display:inline'>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dd26d_level0_col0" class="col_heading level0 col0" >label</th>
#       <th id="T_dd26d_level0_col1" class="col_heading level0 col1" >count</th>
#       <th id="T_dd26d_level0_col2" class="col_heading level0 col2" >unique_value_count</th>
#       <th id="T_dd26d_level0_col3" class="col_heading level0 col3" >unique_percentage</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dd26d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dd26d_row0_col0" class="data row0 col0" >DIAGNOSIS</td>
#       <td id="T_dd26d_row0_col1" class="data row0 col1" >569</td>
#       <td id="T_dd26d_row0_col2" class="data row0 col2" >2</td>
#       <td id="T_dd26d_row0_col3" class="data row0 col3" >0.35%</td>
#     </tr>
#     <tr>
#       <th id="T_dd26d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dd26d_row1_col0" class="data row1 col0" >PERIMETER_WORST</td>
#       <td id="T_dd26d_row1_col1" class="data row1 col1" >569</td>
#       <td id="T_dd26d_row1_col2" class="data row1 col2" >8</td>
#       <td id="T_dd26d_row1_col3" class="data row1 col3" >1.41%</td>
#     </tr>
#     <tr>
#       <th id="T_dd26d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dd26d_row2_col0" class="data row2 col0" >AREA_WORST</td>
#       <td id="T_dd26d_row2_col1" class="data row2 col1" >569</td>
#       <td id="T_dd26d_row2_col2" class="data row2 col2" >8</td>
#       <td id="T_dd26d_row2_col3" class="data row2 col3" >1.41%</td>
#     </tr>
#     <tr>
#       <th id="T_dd26d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dd26d_row3_col0" class="data row3 col0" >RADIUS_WORST</td>
#       <td id="T_dd26d_row3_col1" class="data row3 col1" >569</td>
#       <td id="T_dd26d_row3_col2" class="data row3 col2" >8</td>
#       <td id="T_dd26d_row3_col3" class="data row3 col3" >1.41%</td>
#     </tr>
#     <tr>
#       <th id="T_dd26d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_dd26d_row4_col0" class="data row4 col0" >CONCAVE POINTS_WORST</td>
#       <td id="T_dd26d_row4_col1" class="data row4 col1" >569</td>
#       <td id="T_dd26d_row4_col2" class="data row4 col2" >8</td>
#       <td id="T_dd26d_row4_col3" class="data row4 col3" >1.41%</td>
#     </tr>
#     <tr>
#       <th id="T_dd26d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_dd26d_row5_col0" class="data row5 col0" >CONCAVE POINTS_MEAN</td>
#       <td id="T_dd26d_row5_col1" class="data row5 col1" >569</td>
#       <td id="T_dd26d_row5_col2" class="data row5 col2" >8</td>
#       <td id="T_dd26d_row5_col3" class="data row5 col3" >1.41%</td>
#     </tr>
#     <tr>
#       <th id="T_dd26d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_dd26d_row6_col0" class="data row6 col0" >PERIMETER_MEAN</td>
#       <td id="T_dd26d_row6_col1" class="data row6 col1" >569</td>
#       <td id="T_dd26d_row6_col2" class="data row6 col2" >8</td>
#       <td id="T_dd26d_row6_col3" class="data row6 col3" >1.41%</td>
#     </tr>
#     <tr>
#       <th id="T_dd26d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_dd26d_row7_col0" class="data row7 col0" >AREA_MEAN</td>
#       <td id="T_dd26d_row7_col1" class="data row7 col1" >569</td>
#       <td id="T_dd26d_row7_col2" class="data row7 col2" >8</td>
#       <td id="T_dd26d_row7_col3" class="data row7 col3" >1.41%</td>
#     </tr>
#     <tr>
#       <th id="T_dd26d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_dd26d_row8_col0" class="data row8 col0" >RADIUS_MEAN</td>
#       <td id="T_dd26d_row8_col1" class="data row8 col1" >569</td>
#       <td id="T_dd26d_row8_col2" class="data row8 col2" >8</td>
#       <td id="T_dd26d_row8_col3" class="data row8 col3" >1.41%</td>
#     </tr>
#     <tr>
#       <th id="T_dd26d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_dd26d_row9_col0" class="data row9 col0" >AREA_SE</td>
#       <td id="T_dd26d_row9_col1" class="data row9 col1" >569</td>
#       <td id="T_dd26d_row9_col2" class="data row9 col2" >8</td>
#       <td id="T_dd26d_row9_col3" class="data row9 col3" >1.41%</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ## Train Test Split

# %%
train, test = train_test_split( discretised_data, train_size=0.8, test_size=0.2, random_state=27)

# %% [markdown]
# ## Bayesian Network

# %%
bn = BayesianNetwork(blanket.structure)
bn = bn.fit_node_states(discretised_data)
bn = bn.fit_cpds(train, method="BayesianEstimator", bayes_prior="K2")

# %%
pred = bn.predict(test, 'diagnosis')
true = test['diagnosis']
pred
# Out:
#      diagnosis_prediction
# 191                     0
# 120                     0
# 535                     1
# 282                     1
# 463                     0
# ..                    ...
# 492                     1
# 182                     1
# 443                     0
# 507                     0
# 459                     0
#
# [114 rows x 1 columns]

# %%
print('Recall: {:.2f}'.format(recall_score(y_true=true, y_pred=pred)))
print('F1: {:.2f} '.format(f1_score(y_true=true, y_pred=pred)))
print('Accuracy: {:.2f} '.format(accuracy_score(y_true=true, y_pred=pred)))
print('Precision: {:.2f} '.format(precision_score(y_true=true, y_pred=pred)))
# Out:
# Recall: 0.64
# F1: 0.78
# Accuracy: 0.86
# Precision: 1.00

# %% [markdown]
# ## Inference

# %%
ie = InferenceEngine(bn)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# c:\Users\rafaa\Desktop\10AcademyFolder\Week8\Tech\Causal-Inference\notebooks\Causal Learning.ipynb Cell 64 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/rafaa/Desktop/10AcademyFolder/Week8/Tech/Causal-Inference/notebooks/Causal%20Learning.ipynb#ch0000063?line=0'>1</a> ie = InferenceEngine(bn)
#
# File c:\Users\rafaa\anaconda3\envs\my_venv\lib\site-packages\causalnex\inference\inference.py:110, in InferenceEngine.__init__(self, bn)
#     108 bad_nodes = [node for node in bn.nodes if not re.match("^[0-9a-zA-Z_]+$", node)]
#     109 if bad_nodes:
# --> 110     raise ValueError(
#     111         "Variable names must match ^[0-9a-zA-Z_]+$ - please fix the "
#     112         "following nodes: {0}".format(bad_nodes)
#     113     )
#     115 if not bn.cpds:
#     116     raise ValueError(
#     117         "Bayesian Network does not contain any CPDs. You should fit CPDs "
#     118         "before doing inference (see `BayesianNetwork.fit_cpds`)."
#     119     )
#
# ValueError: Variable names must match ^[0-9a-zA-Z_]+$ - please fix the following nodes: ['concave points_mean']

# %% [markdown]
# What would be the Outcome if all people actually had healthy weight? — If all people were with healthy weight, there will be less positive diagnosis.(from 0.42 to 0.30)

# %%
observation_1 = {"area_mean": 1, "area_se": 1, "area_worst": 1}
observation_2 = {"area_mean": 2, "area_se": 2, "area_worst": 2}
marginals = ie.query([observation_1, observation_2])

# %%
for m in marginals:
  print(m['diagnosis'])
